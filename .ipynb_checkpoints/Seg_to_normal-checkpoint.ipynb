# %%
import matplotlib

# %%
import numpy as np
from PIL import Image
from skimage.io import imread
mask_img=imread('img_seg.png')
img=imread('img.jpg')

# %%
def inpaint(originalImage, mask):
    [rows, columns, channels] = originalImage.shape
    result = np.zeros((rows,columns,channels))
    for row in range(rows):
        for column in range(columns):
            if(mask[row,column]==1):
                result[row,column] = originalImage[row,column]
            else:
                result[row,column] = (0,0,255)
    return result

# %%
new_img=inpaint(img, mask_img)
new_img
# Out:
# array([[[237., 237., 239.],
#         [230., 230., 232.],
#         [227., 227., 229.],
#         ...,
#         [227., 226., 234.],
#         [230., 229., 237.],
#         [237., 236., 244.]],
#
#        [[228., 228., 230.],
#         [221., 221., 223.],
#         [218., 218., 220.],
#         ...,
#         [216., 215., 223.],
#         [220., 219., 227.],
#         [226., 225., 233.]],
#
#        [[228., 228., 230.],
#         [222., 222., 224.],
#         [218., 218., 220.],
#         ...,
#         [215., 214., 222.],
#         [219., 218., 226.],
#         [225., 224., 232.]],
#
#        ...,
#
#        [[232., 233., 235.],
#         [226., 227., 229.],
#         [224., 225., 227.],
#         ...,
#         [219., 218., 224.],
#         [223., 222., 228.],
#         [230., 229., 235.]],
#
#        [[232., 233., 235.],
#         [226., 227., 229.],
#         [224., 225., 227.],
#         ...,
#         [217., 216., 222.],
#         [221., 220., 226.],
#         [228., 227., 233.]],
#
#        [[241., 242., 244.],
#         [235., 236., 238.],
#         [233., 234., 236.],
#         ...,
#         [225., 224., 230.],
#         [229., 228., 234.],
#         [236., 235., 241.]]])

# %%
created_image = Image.fromarray(new_img,mode='RGBA')
#created_image.save('new.png')
created_image.show()

# %%
from matplotlib import pyplot as plt
import cv2
#plt.imshow(new_img, interpolation='nearest')
#cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
new_img_sl = np.uint8(new_img)
plt.imshow(cv2.cvtColor(new_img_sl, cv2.COLOR_BGR2RGB))
plt.show()
